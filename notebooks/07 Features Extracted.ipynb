# %%
import numpy as np
np.set_printoptions(threshold=np.nan)

features = np.load('/imatge/amontes/work/datasets/ActivityNet/v1.3/features/0n3VRoYYYGU.npy')
print(features.shape)
# Out:
# (435, 4096)

# %%
print(features[0])
# Out:
# [  1.37603664e+00   4.74674761e-01   2.68462658e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   3.08817053e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   2.08979905e-01   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   3.40022922e-01
#    0.00000000e+00   0.00000000e+00   3.90645683e-01   0.00000000e+00
#    1.42174053e+00   0.00000000e+00   0.00000000e+00   5.55361152e-01
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   1.46790981e-01   1.82704401e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   2.56541491e+00
# ...
